# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Churn Cohort Analysis

# %%
df = pd.read_csv(r'D:\Courses\Data-Science_Tech\INeuron_Courses\MACHING_LEARNING_LIVE-CLASS\PROJECT\ML_CODE\ML_Live_Class\data\Telco-Customer-Churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7032 entries, 0 to 7031
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7032.000000  7032.000000     7032.000000   7032.000000
# mean        0.162400    32.421786       64.798208   2283.300441
# std         0.368844    24.545260       30.085974   2266.771362
# min         0.000000     1.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.587500    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.862500   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %%
df.isnull().sum() #Null value check, No missing values
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
sns.countplot(data = df,x='Churn') # Not much imbalanced. Can try some balacing techniques later.
# BaggingBalancedClassifier,Smote for balancing
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='count'>

# %%
sns.boxplot(data = df, x = 'Churn',y='TotalCharges')
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='TotalCharges'>

# %%
plt.figure(figsize =(8,6),dpi = 150)
sns.boxplot(data = df, x = 'Contract',y='TotalCharges',hue='Churn')
plt.legend()

# %% [markdown]
# #### Observations
# Month-month not much difference in total charges. Also equal chances of leaving.
#
# One year contract charges are more and liklihood of churning is more.
#
# Two year people churning are less and total charges are less. In Two year people leaving are with more total Charges.

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
corr_df = pd.get_dummies(df[['gender', 'Partner', 'Dependents',
        'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod', 'Churn']]).corr()
corr_df.head()
# Out:
#                gender_Female  gender_Male  Partner_No  Partner_Yes  \
# gender_Female       1.000000    -1.000000   -0.001379     0.001379
# gender_Male        -1.000000     1.000000    0.001379    -0.001379
# Partner_No         -0.001379     0.001379    1.000000    -1.000000
# Partner_Yes         0.001379    -0.001379   -1.000000     1.000000
# Dependents_No       0.010349    -0.010349    0.452269    -0.452269
#
#                Dependents_No  Dependents_Yes  PhoneService_No  \
# gender_Female       0.010349       -0.010349        -0.007515
# gender_Male        -0.010349        0.010349         0.007515
# Partner_No          0.452269       -0.452269         0.018397
# Partner_Yes        -0.452269        0.452269        -0.018397
# Dependents_No       1.000000       -1.000000        -0.001078
#
#                PhoneService_Yes  MultipleLines_No  \
# gender_Female          0.007515         -0.004335
# gender_Male           -0.007515          0.004335
# ...

# %%
corr_df['Churn_Yes'].sort_values()[1:-1]
# Out:
# Contract_Two year                         -0.301552
# StreamingTV_No internet service           -0.227578
# OnlineBackup_No internet service          -0.227578
# StreamingMovies_No internet service       -0.227578
# OnlineSecurity_No internet service        -0.227578
# InternetService_No                        -0.227578
# DeviceProtection_No internet service      -0.227578
# TechSupport_No internet service           -0.227578
# PaperlessBilling_No                       -0.191454
# Contract_One year                         -0.178225
# OnlineSecurity_Yes                        -0.171270
# TechSupport_Yes                           -0.164716
# Dependents_Yes                            -0.163128
# Partner_Yes                               -0.149982
# PaymentMethod_Credit card (automatic)     -0.134687
# InternetService_DSL                       -0.124141
# PaymentMethod_Bank transfer (automatic)   -0.118136
# PaymentMethod_Mailed check                -0.090773
# ...

# %%
plt.figure(figsize =(10,8),dpi = 150)
sns.barplot(x = corr_df['Churn_Yes'].sort_values().iloc[1:-1].index,y = corr_df['Churn_Yes'].sort_values().iloc[1:-1].values)
plt.title("Feature corelation w.r.to Churn_Yes")
plt.xticks(rotation =90);

# %%
plt.figure(figsize =(10,6),dpi = 150)
sns.histplot(data = df,x='tenure',bins=40)
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='Count'>

# %%
sns.displot(data = df,x = 'tenure',bins=60,col='Contract',row='Churn')

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
plt.figure(figsize =(10,6),dpi = 150)
sns.scatterplot(data = df,x='MonthlyCharges',y='TotalCharges',hue='Churn',alpha=0.6)
# Out:
# <AxesSubplot:xlabel='MonthlyCharges', ylabel='TotalCharges'>

# %%
no_churn = df.groupby(['Churn','tenure']).count().transpose()['No']
yes_churn = df.groupby(['Churn','tenure']).count().transpose()['Yes']

# %%
churn_rate = yes_churn/(no_churn+yes_churn)*100 #Yes_churn percentage in total
churn_rate
# Out:
# tenure                   1          2     3          4          5          6   \
# customerID        61.990212  51.680672  47.0  47.159091  48.120301  36.363636
# gender            61.990212  51.680672  47.0  47.159091  48.120301  36.363636
# SeniorCitizen     61.990212  51.680672  47.0  47.159091  48.120301  36.363636
# Partner           61.990212  51.680672  47.0  47.159091  48.120301  36.363636
# Dependents        61.990212  51.680672  47.0  47.159091  48.120301  36.363636
# PhoneService      61.990212  51.680672  47.0  47.159091  48.120301  36.363636
# MultipleLines     61.990212  51.680672  47.0  47.159091  48.120301  36.363636
# InternetService   61.990212  51.680672  47.0  47.159091  48.120301  36.363636
# OnlineSecurity    61.990212  51.680672  47.0  47.159091  48.120301  36.363636
# OnlineBackup      61.990212  51.680672  47.0  47.159091  48.120301  36.363636
# DeviceProtection  61.990212  51.680672  47.0  47.159091  48.120301  36.363636
# ...

# %%
churn_rate=churn_rate.transpose()['customerID']
churn_rate
# Out:
# tenure
# 1     61.990212
# 2     51.680672
# 3     47.000000
# 4     47.159091
# 5     48.120301
#         ...
# 68     9.000000
# 69     8.421053
# 70     9.243697
# 71     3.529412
# 72     1.657459
# Name: customerID, Length: 72, dtype: float64

# %%
plt.plot(churn_rate.index,churn_rate.values)

# %%
def cohort (tenure):
    if tenure <13:
        return "O-12 Months"
    elif tenure < 25:
        return "12-24 Months"
    elif tenure < 49:
        return "24-48 Months"
    else:
        return "Over 48 Months"

# %%
df['Tenure_Cohort'] = df['tenure'].apply(cohort)
df[['Tenure_Cohort','tenure']].head(10)
# Out:
#     Tenure_Cohort  tenure
# 0     O-12 Months       1
# 1    24-48 Months      34
# 2     O-12 Months       2
# 3    24-48 Months      45
# 4     O-12 Months       2
# 5     O-12 Months       8
# 6    12-24 Months      22
# 7     O-12 Months      10
# 8    24-48 Months      28
# 9  Over 48 Months      62

# %%
plt.figure(figsize =(10,6),dpi = 150)
sns.scatterplot(data = df,x='MonthlyCharges',y='TotalCharges',hue='Tenure_Cohort',alpha=0.6)
# Out:
# <AxesSubplot:xlabel='MonthlyCharges', ylabel='TotalCharges'>

# %%
plt.figure(figsize =(10,6),dpi = 150)
sns.countplot(data = df, x ='Tenure_Cohort',hue ='Churn')
# Out:
# <AxesSubplot:xlabel='Tenure_Cohort', ylabel='count'>

# %%
plt.figure(figsize =(10,6),dpi = 150)
sns.catplot(data=df,x='Tenure_Cohort',hue='Churn',col ='Contract',kind='count')
