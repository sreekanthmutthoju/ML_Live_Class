# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'D:\Courses\Data-Science_Tech\INeuron_Courses\MACHING_LEARNING_LIVE-CLASS\PROJECT\ML_CODE\ML_Live_Class\data\wine_fraud.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality type
# 0      9.4   Legit  red
# 1      9.8   Legit  red
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   object
#  12  type                  6497 non-null   object
# dtypes: float64(11), object(2)
# memory usage: 660.0+ KB

# %%
df['quality'].value_counts() # Highly imbalanced case
# Out:
# Legit    6251
# Fraud     246
# Name: quality, dtype: int64

# %%
sns.countplot(x='quality',data=df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %%
sns.countplot(x='type',data=df,hue ='quality')
# Out:
# <AxesSubplot:xlabel='type', ylabel='count'>

# %%
reds = df[df['type']=='red']
whites = df[df['type']=='white']

# %%
reds[reds['quality']=='Fraud'] #No of Frauds with red type
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 18              7.4             0.590         0.08             4.4      0.086
# 38              5.7             1.130         0.09             1.5      0.172
# 41              8.8             0.610         0.30             2.8      0.088
# 45              4.6             0.520         0.15             2.1      0.054
# 73              8.3             0.675         0.26             2.1      0.084
# ...             ...               ...          ...             ...        ...
# 1480            5.6             0.620         0.03             1.5      0.080
# 1482            7.2             0.580         0.54             2.1      0.114
# 1484            6.8             0.910         0.06             2.0      0.060
# 1505            6.7             0.760         0.02             1.8      0.078
# 1521            6.9             0.480         0.20             1.9      0.082
#
# ...

# %%
whites[whites['quality']=='Fraud'] # No of frauds with white type
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1645            6.2             0.450         0.26            4.40      0.063
# 1697            9.8             0.360         0.46           10.50      0.038
# 1714            5.5             0.485         0.00            1.50      0.065
# 1746            6.4             0.595         0.14            5.20      0.058
# 1771            7.6             0.480         0.37            0.80      0.037
# ...             ...               ...          ...             ...        ...
# 6373            7.1             0.240         0.34            1.20      0.045
# 6378            6.0             0.590         0.00            0.80      0.037
# 6403            6.0             0.350         0.46            0.90      0.033
# 6438            5.2             0.405         0.15            1.45      0.038
# 6477            6.2             0.530         0.02            0.90      0.035
#
# ...

# %%
len(whites[whites['quality']=='Fraud'])/len(whites)*100 #Percent of frauds in white type
# Out:
# 3.7362188648427925

# %%
len(reds[reds['quality']=='Fraud'])/len(reds)*100 #percent of frauds in reds
# Out:
# 3.9399624765478425

# %%
df['Fraud'] = df['quality'].map({'Legit':0,'Fraud':1}) #Creating a numerical columns so correlation can be calculated
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality type  Fraud
# 0      9.4   Legit  red      0
# ...

# %%
corr = df.corr()['Fraud'][:-1].sort_values() #correlation of all features wrto fraud
corr
# Out:
# free sulfur dioxide    -0.085204
# citric acid            -0.061789
# alcohol                -0.051141
# residual sugar         -0.048756
# total sulfur dioxide   -0.035252
# sulphates              -0.034046
# density                 0.016351
# pH                      0.020107
# fixed acidity           0.021794
# chlorides               0.034499
# volatile acidity        0.151228
# Name: Fraud, dtype: float64

# %%
df.corr()['Fraud'][:-1].sort_values().barplot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\Courses\Data-Science_Tech\INeuron_Courses\MACHING_LEARNING_LIVE-CLASS\PROJECT\ML_CODE\ML_Live_Class\SVM\SVM_Wine_Project.ipynb Cell 14' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Courses/Data-Science_Tech/INeuron_Courses/MACHING_LEARNING_LIVE-CLASS/PROJECT/ML_CODE/ML_Live_Class/SVM/SVM_Wine_Project.ipynb#ch0000014?line=0'>1</a> df.corr()['Fraud'][:-1].sort_values().barplot()
#
# File ~\.conda\envs\mlenv\lib\site-packages\pandas\core\generic.py:5583, in NDFrame.__getattr__(self, name)
#    <a href='file:///c%3A/Users/SREEKANTH/.conda/envs/mlenv/lib/site-packages/pandas/core/generic.py?line=5575'>5576</a> if (
#    <a href='file:///c%3A/Users/SREEKANTH/.conda/envs/mlenv/lib/site-packages/pandas/core/generic.py?line=5576'>5577</a>     name not in self._internal_names_set
# ...

# %%
plt.figure(figsize=(8,6),dpi =150)
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df = df.drop('Fraud',axis = 1) 
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality type
# 0      9.4   Legit  red
# 1      9.8   Legit  red
# ...

# %%
df['type'] = pd.get_dummies(df['type'],drop_first=True) #Encoding
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality  type
# 0      9.4   Legit     0
# 1      9.8   Legit     0
# ...

# %%
df['type'].unique()
# Out:
# array([0, 1], dtype=uint8)

# %%
X = df.drop('quality',axis=1)
y = df['quality']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.15,random_state=1)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print(X_train_scaled.shape)
print('\n',X_test_scaled.shape)
# Out:
# (5522, 12)
#
#  (975, 12)

# %%
from sklearn.svm import SVC

# %%
svc = SVC(class_weight='balanced')

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'C':[0.001,0.01,0.1,10]}

# %%
grid_model = GridSearchCV(svc,param_grid=param_grid)

# %%
grid_model.fit(X_train_scaled,y_train)
# Out:
# GridSearchCV(estimator=SVC(class_weight='balanced'),
#              param_grid={'C': [0.001, 0.01, 0.1, 10]})

# %%
grid_model.best_params_
# Out:
# {'C': 10}

# %%
from sklearn.metrics import confusion_matrix,classification_report,plot_confusion_matrix

# %%
grid_preds = grid_model.predict(X_test_scaled)

# %%
confusion_matrix(y_test,grid_preds)
# Out:
# array([[ 16,  22],
#        [ 83, 854]], dtype=int64)

# %%
plot_confusion_matrix(grid_model,y_test,grid_preds)
# Out:
# C:\Users\SREEKANTH\.conda\envs\mlenv\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Courses\Data-Science_Tech\INeuron_Courses\MACHING_LEARNING_LIVE-CLASS\PROJECT\ML_CODE\ML_Live_Class\SVM\SVM_Wine_Project.ipynb Cell 33' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Courses/Data-Science_Tech/INeuron_Courses/MACHING_LEARNING_LIVE-CLASS/PROJECT/ML_CODE/ML_Live_Class/SVM/SVM_Wine_Project.ipynb#ch0000033?line=0'>1</a> plot_confusion_matrix(grid_model,y_test,grid_preds)
#
# ...

# %%
print(classification_report(y_test,grid_preds))
# Out:
#               precision    recall  f1-score   support
#
#        Fraud       0.16      0.42      0.23        38
#        Legit       0.97      0.91      0.94       937
#
#     accuracy                           0.89       975
#    macro avg       0.57      0.67      0.59       975
# weighted avg       0.94      0.89      0.91       975
